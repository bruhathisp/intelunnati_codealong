# %% [markdown]
# # Importing the required libraries

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.datasets import FashionMNIST
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# %%
import torch.nn as nn

class FashionMNISTCNN(nn.Module):
    def __init__(self):
        super(FashionMNISTCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(32 * 7 * 7, 128)
        self.fc2 = nn.Linear(128, 10)
        self.relu = nn.ReLU()
        self.nn_layers = nn.ModuleList()

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.pool(x)
        x = self.relu(self.conv2(x))
        x = self.pool(x)
        x = self.flatten(x)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %% [markdown]
# <h1>Set the device</h1>

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# <h1>Set the hyperparameters</h1>

# %%
batch_size = 64
learning_rate = 0.01
rho = 0.01
epochs = 100

# %% [markdown]
# # Load the Fashion MNIST dataset
#  Transform the data to tensors and normalize it

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

dataset = FashionMNIST(root="./data", train=True, download=True, transform=transform)

# %% [markdown]
# # Divide the dataset into training (80%) and validation (20%) sets

# %%
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

# %% [markdown]
# # Create data loaders for training and validation sets

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# #Define the model

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.datasets import FashionMNIST
from torchvision import transforms


def create_model():
    model = FashionMNISTCNN()
    return model

# %% [markdown]
# # Define the SAM optimizer

# %%
class SAM(optim.Optimizer):
    def __init__(self, params, base_optimizer, rho=0.01, lr=0.01):
        self.rho = rho
        defaults = dict(lr=lr)
        super(SAM, self).__init__(params, defaults)
        self.base_optimizer = base_optimizer(self.param_groups, lr=lr)

    def step(self, closure=None):
        loss = None
        if closure is not None:
            loss = closure()

        for group in self.param_groups:
            for p in group['params']:
                if p.grad is None:
                    continue
                grad = p.grad.data
                p_data_fp32 = p.data
                if p_data_fp32.dtype != torch.float32:
                    p_data_fp32 = p_data_fp32.float()

                grad.add_(p_data_fp32, alpha=self.rho)
                
                self.base_optimizer.step(closure)

                p.data.copy_(p_data_fp32)

        return loss

# %% [markdown]
# # Perform hyperparameter tuning and training for one iteration

# %% [markdown]
# ## Training loop with Intel optimization

# %%
print("Training with Intel optimization...")
# best_accuracy = 0.0
# best_hyperparameters = None



def train_model(model, train_loader, val_loader, criterion, optimizer, epochs):
    best_accuracy_with_opt = 0.0
    best_hyperparameters_with_opt = None

    for epoch in range(epochs):
        model.train()  # Set the model in training mode explicitly
        total_correct = 0
        total_samples = 0
        running_loss = 0.0

        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)

            optimizer.zero_grad()

            output = model(data)
            loss = criterion(output, target)

            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(output, 1)
            total_samples += target.size(0)
            total_correct += (predicted == target).sum().item()

        train_loss = running_loss / len(train_loader)
        train_accuracy = 100.0 * total_correct / total_samples

        model.eval()  # Set the model in evaluation mode explicitly
        val_loss = 0.0
        total_correct = 0
        total_samples = 0

        with torch.no_grad():
            for data, target in val_loader:
                data, target = data.to(device), target.to(device)

                output = model(data)
                loss = criterion(output, target)

                val_loss += loss.item()
                _, predicted = torch.max(output, 1)
                total_samples += target.size(0)
                total_correct += (predicted == target).sum().item()

        val_loss /= len(val_loader)
        val_accuracy = 100.0 * total_correct / total_samples

        print(f"Epoch {epoch + 1}/{epochs} completed. Training Accuracy: {train_accuracy:.2f}%, Validation Accuracy: {val_accuracy:.2f}%")

        if val_accuracy > best_accuracy_with_opt:
            best_accuracy_with_opt = val_accuracy
            best_hyperparameters_with_opt = (batch_size, learning_rate, rho) 

    print("Hyperparameter tuning and training with Intel optimization complete.")
    print("Best Hyperparameters (With Optimization):")
    print("Batch Size:", best_hyperparameters_with_opt[0])
    print("Learning Rate:", best_hyperparameters_with_opt[1])
    print("Rho:", best_hyperparameters_with_opt[2])

# Now initialize the model and optimizer
model = create_model().to(device)
optimizer = SAM(model.parameters(), base_optimizer=optim.SGD, rho=rho, lr=learning_rate)

# Define the criterion (loss function)
criterion = nn.CrossEntropyLoss()

# Train the model
train_model(model, train_loader, val_loader, criterion, optimizer, epochs)




for batch_size in [32, 64]:  # Adjust batch size options for smaller values
    for learning_rate in [0.01, 0.1]:  # Increase learning rate options
        for rho in [0.001, 0.01]:  # Decrease rho options
            model = FashionMNISTCNN().to(device)
            optimizer = SAM(model.parameters(), base_optimizer=optim.SGD, rho=rho, lr=learning_rate)
            train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

            criterion = nn.CrossEntropyLoss()

            for epoch in range(epochs):
                model.train()
                total_correct = 0
                total_samples = 0
                running_loss = 0.0

                for batch_idx, (data, target) in enumerate(train_loader):
                    data, target = data.to(device), target.to(device)

                    optimizer.zero_grad()

                    output = model(data)
                    loss = criterion(output, target)

                    loss.backward()
                    optimizer.step()

                    running_loss += loss.item()
                    _, predicted = torch.max(output, 1)
                    total_samples += target.size(0)
                    total_correct += (predicted == target).sum().item()

                train_loss = running_loss / len(train_loader)
                train_accuracy = 100.0 * total_correct / total_samples

                model.eval()
                val_loss = 0.0
                total_correct = 0
                total_samples = 0

                with torch.no_grad():
                    for data, target in val_loader:
                        data, target = data.to(device), target.to(device)
                        output = model(data)
                        loss = criterion(output, target)
                        val_loss += loss.item()

                        _, predicted = torch.max(output, 1)
                        total_samples += target.size(0)
                        total_correct += (predicted == target).sum().item()

                val_loss /= len(val_loader)
                val_accuracy = 100.0 * total_correct / total_samples

                print(f"Epoch {epoch + 1}/{epochs} completed. Training Accuracy: {train_accuracy:.2f}%, Validation Accuracy: {val_accuracy:.2f}%")

            print(f"Hyperparameters: Batch Size={batch_size}, Learning Rate={learning_rate}, Rho={rho}, Validation Accuracy={val_accuracy:.4f}")

            if val_accuracy > best_accuracy:
                best_accuracy = val_accuracy
                best_hyperparameters = (batch_size, learning_rate, rho)

            

            # Break after one iteration
            break
        # Break after one iteration
        break
    # Break after one iteration
    break
# Out:
# Training with Intel optimization...
# Epoch 1/100 completed. Training Accuracy: 79.84%, Validation Accuracy: 86.19%
# Epoch 2/100 completed. Training Accuracy: 87.83%, Validation Accuracy: 89.03%
# Epoch 3/100 completed. Training Accuracy: 89.53%, Validation Accuracy: 89.77%
# Epoch 4/100 completed. Training Accuracy: 90.50%, Validation Accuracy: 90.38%
# Epoch 5/100 completed. Training Accuracy: 91.29%, Validation Accuracy: 90.97%
# Epoch 6/100 completed. Training Accuracy: 91.87%, Validation Accuracy: 90.83%
# Epoch 7/100 completed. Training Accuracy: 92.46%, Validation Accuracy: 91.41%
# Epoch 8/100 completed. Training Accuracy: 92.95%, Validation Accuracy: 91.23%
# Epoch 9/100 completed. Training Accuracy: 93.38%, Validation Accuracy: 91.95%
# Epoch 10/100 completed. Training Accuracy: 93.64%, Validation Accuracy: 90.72%
# Epoch 11/100 completed. Training Accuracy: 94.00%, Validation Accuracy: 90.35%
# Epoch 12/100 completed. Training Accuracy: 94.26%, Validation Accuracy: 91.40%
# Epoch 13/100 completed. Training Accuracy: 94.65%, Validation Accuracy: 91.78%
# Epoch 14/100 completed. Training Accuracy: 95.02%, Validation Accuracy: 91.50%
# Epoch 15/100 completed. Training Accuracy: 95.12%, Validation Accuracy: 91.24%
# Epoch 16/100 completed. Training Accuracy: 95.20%, Validation Accuracy: 89.59%
# Epoch 17/100 completed. Training Accuracy: 95.66%, Validation Accuracy: 91.56%
# Epoch 18/100 completed. Training Accuracy: 95.95%, Validation Accuracy: 91.55%
# Epoch 19/100 completed. Training Accuracy: 96.23%, Validation Accuracy: 91.38%
# Epoch 20/100 completed. Training Accuracy: 96.32%, Validation Accuracy: 91.62%
# Epoch 21/100 completed. Training Accuracy: 96.52%, Validation Accuracy: 92.12%
# Epoch 22/100 completed. Training Accuracy: 96.79%, Validation Accuracy: 91.43%
# Epoch 23/100 completed. Training Accuracy: 96.88%, Validation Accuracy: 90.75%
# Epoch 24/100 completed. Training Accuracy: 97.11%, Validation Accuracy: 91.66%
# Epoch 25/100 completed. Training Accuracy: 97.21%, Validation Accuracy: 91.39%
# Epoch 26/100 completed. Training Accuracy: 97.26%, Validation Accuracy: 91.42%
# Epoch 27/100 completed. Training Accuracy: 97.45%, Validation Accuracy: 91.58%
# Epoch 28/100 completed. Training Accuracy: 97.69%, Validation Accuracy: 91.46%
# Epoch 29/100 completed. Training Accuracy: 97.72%, Validation Accuracy: 91.67%
# Epoch 30/100 completed. Training Accuracy: 97.62%, Validation Accuracy: 91.35%
# Epoch 31/100 completed. Training Accuracy: 97.87%, Validation Accuracy: 91.72%
# Epoch 32/100 completed. Training Accuracy: 97.95%, Validation Accuracy: 91.16%
# Epoch 33/100 completed. Training Accuracy: 98.00%, Validation Accuracy: 91.50%
# Epoch 34/100 completed. Training Accuracy: 98.16%, Validation Accuracy: 91.94%
# Epoch 35/100 completed. Training Accuracy: 98.17%, Validation Accuracy: 91.54%
# Epoch 36/100 completed. Training Accuracy: 98.22%, Validation Accuracy: 91.83%
# Epoch 37/100 completed. Training Accuracy: 98.28%, Validation Accuracy: 91.92%
# Epoch 38/100 completed. Training Accuracy: 98.26%, Validation Accuracy: 91.64%
# Epoch 39/100 completed. Training Accuracy: 98.38%, Validation Accuracy: 91.76%
# Epoch 40/100 completed. Training Accuracy: 98.40%, Validation Accuracy: 91.48%
# Epoch 41/100 completed. Training Accuracy: 98.51%, Validation Accuracy: 91.68%
# Epoch 42/100 completed. Training Accuracy: 98.54%, Validation Accuracy: 91.33%
# Epoch 43/100 completed. Training Accuracy: 98.58%, Validation Accuracy: 91.62%
# Epoch 44/100 completed. Training Accuracy: 98.58%, Validation Accuracy: 91.49%
# Epoch 45/100 completed. Training Accuracy: 98.67%, Validation Accuracy: 91.26%
# Epoch 46/100 completed. Training Accuracy: 98.54%, Validation Accuracy: 91.78%
# Epoch 47/100 completed. Training Accuracy: 98.68%, Validation Accuracy: 91.56%
# Epoch 48/100 completed. Training Accuracy: 98.71%, Validation Accuracy: 91.46%
# Epoch 49/100 completed. Training Accuracy: 98.69%, Validation Accuracy: 91.79%
# Epoch 50/100 completed. Training Accuracy: 98.74%, Validation Accuracy: 91.76%
# Epoch 51/100 completed. Training Accuracy: 98.62%, Validation Accuracy: 91.62%
# Epoch 52/100 completed. Training Accuracy: 98.67%, Validation Accuracy: 91.75%
# Epoch 53/100 completed. Training Accuracy: 98.78%, Validation Accuracy: 91.62%
# Epoch 54/100 completed. Training Accuracy: 98.73%, Validation Accuracy: 91.64%
# Epoch 55/100 completed. Training Accuracy: 98.86%, Validation Accuracy: 91.53%
# Epoch 56/100 completed. Training Accuracy: 98.82%, Validation Accuracy: 91.50%
# Epoch 57/100 completed. Training Accuracy: 98.88%, Validation Accuracy: 91.85%
# Epoch 58/100 completed. Training Accuracy: 98.86%, Validation Accuracy: 90.75%
# Epoch 59/100 completed. Training Accuracy: 98.88%, Validation Accuracy: 91.53%
# Epoch 60/100 completed. Training Accuracy: 98.97%, Validation Accuracy: 92.03%
# Epoch 61/100 completed. Training Accuracy: 98.92%, Validation Accuracy: 91.44%
# Epoch 62/100 completed. Training Accuracy: 98.95%, Validation Accuracy: 91.61%
# Epoch 63/100 completed. Training Accuracy: 98.96%, Validation Accuracy: 91.86%
# Epoch 64/100 completed. Training Accuracy: 98.86%, Validation Accuracy: 91.71%
# Epoch 65/100 completed. Training Accuracy: 98.96%, Validation Accuracy: 90.23%
# Epoch 66/100 completed. Training Accuracy: 98.91%, Validation Accuracy: 91.50%
# Epoch 67/100 completed. Training Accuracy: 98.96%, Validation Accuracy: 91.71%
# Epoch 68/100 completed. Training Accuracy: 98.86%, Validation Accuracy: 91.50%
# Epoch 69/100 completed. Training Accuracy: 98.94%, Validation Accuracy: 90.09%
# Epoch 70/100 completed. Training Accuracy: 99.01%, Validation Accuracy: 91.98%
# Epoch 71/100 completed. Training Accuracy: 99.10%, Validation Accuracy: 91.42%
# Epoch 72/100 completed. Training Accuracy: 99.12%, Validation Accuracy: 91.16%
# Epoch 73/100 completed. Training Accuracy: 98.89%, Validation Accuracy: 92.02%
# Epoch 74/100 completed. Training Accuracy: 98.89%, Validation Accuracy: 91.49%
# Epoch 75/100 completed. Training Accuracy: 98.97%, Validation Accuracy: 91.76%
# Epoch 76/100 completed. Training Accuracy: 99.10%, Validation Accuracy: 91.08%
# Epoch 77/100 completed. Training Accuracy: 99.15%, Validation Accuracy: 91.62%
# Epoch 78/100 completed. Training Accuracy: 99.06%, Validation Accuracy: 91.78%
# Epoch 79/100 completed. Training Accuracy: 99.00%, Validation Accuracy: 91.55%
# Epoch 80/100 completed. Training Accuracy: 99.08%, Validation Accuracy: 90.86%
# Epoch 81/100 completed. Training Accuracy: 99.08%, Validation Accuracy: 90.79%
# Epoch 82/100 completed. Training Accuracy: 98.94%, Validation Accuracy: 91.33%
# Epoch 83/100 completed. Training Accuracy: 99.07%, Validation Accuracy: 92.07%
# Epoch 84/100 completed. Training Accuracy: 99.08%, Validation Accuracy: 91.41%
# Epoch 85/100 completed. Training Accuracy: 99.06%, Validation Accuracy: 91.49%
# Epoch 86/100 completed. Training Accuracy: 99.11%, Validation Accuracy: 91.58%
# Epoch 87/100 completed. Training Accuracy: 99.15%, Validation Accuracy: 91.76%
# Epoch 88/100 completed. Training Accuracy: 99.12%, Validation Accuracy: 91.62%
# Epoch 89/100 completed. Training Accuracy: 99.00%, Validation Accuracy: 91.68%
# Epoch 90/100 completed. Training Accuracy: 99.14%, Validation Accuracy: 91.59%
# Epoch 91/100 completed. Training Accuracy: 99.15%, Validation Accuracy: 91.83%
# Epoch 92/100 completed. Training Accuracy: 99.15%, Validation Accuracy: 91.53%
# Epoch 93/100 completed. Training Accuracy: 99.02%, Validation Accuracy: 91.78%
# Epoch 94/100 completed. Training Accuracy: 98.97%, Validation Accuracy: 91.26%
# Epoch 95/100 completed. Training Accuracy: 99.02%, Validation Accuracy: 91.53%
# Epoch 96/100 completed. Training Accuracy: 99.16%, Validation Accuracy: 91.73%
# Epoch 97/100 completed. Training Accuracy: 99.20%, Validation Accuracy: 92.22%
# Epoch 98/100 completed. Training Accuracy: 99.23%, Validation Accuracy: 91.34%
# Epoch 99/100 completed. Training Accuracy: 99.24%, Validation Accuracy: 91.47%
# Epoch 100/100 completed. Training Accuracy: 99.13%, Validation Accuracy: 91.88%
# Hyperparameter tuning and training with Intel optimization complete.
# Best Hyperparameters (With Optimization):
# Batch Size: 32
# Learning Rate: 0.01
# Rho: 0.001
# Epoch 1/100 completed. Training Accuracy: 80.14%, Validation Accuracy: 85.65%
# Epoch 2/100 completed. Training Accuracy: 88.03%, Validation Accuracy: 87.72%
# Epoch 3/100 completed. Training Accuracy: 89.66%, Validation Accuracy: 89.85%
# Epoch 4/100 completed. Training Accuracy: 90.75%, Validation Accuracy: 90.68%
# Epoch 5/100 completed. Training Accuracy: 91.35%, Validation Accuracy: 90.51%
# Epoch 6/100 completed. Training Accuracy: 91.99%, Validation Accuracy: 91.08%
# Epoch 7/100 completed. Training Accuracy: 92.55%, Validation Accuracy: 90.91%
# Epoch 8/100 completed. Training Accuracy: 93.06%, Validation Accuracy: 90.60%
# Epoch 9/100 completed. Training Accuracy: 93.35%, Validation Accuracy: 91.17%
# Epoch 10/100 completed. Training Accuracy: 93.85%, Validation Accuracy: 89.73%
# Epoch 11/100 completed. Training Accuracy: 94.09%, Validation Accuracy: 90.59%
# Epoch 12/100 completed. Training Accuracy: 94.55%, Validation Accuracy: 91.54%
# Epoch 13/100 completed. Training Accuracy: 94.68%, Validation Accuracy: 91.09%
# Epoch 14/100 completed. Training Accuracy: 94.97%, Validation Accuracy: 91.08%
# Epoch 15/100 completed. Training Accuracy: 95.33%, Validation Accuracy: 91.66%
# Epoch 16/100 completed. Training Accuracy: 95.63%, Validation Accuracy: 91.77%
# Epoch 17/100 completed. Training Accuracy: 95.90%, Validation Accuracy: 91.53%
# Epoch 18/100 completed. Training Accuracy: 96.08%, Validation Accuracy: 91.91%
# Epoch 19/100 completed. Training Accuracy: 96.41%, Validation Accuracy: 91.85%
# Epoch 20/100 completed. Training Accuracy: 96.52%, Validation Accuracy: 91.85%
# Epoch 21/100 completed. Training Accuracy: 96.66%, Validation Accuracy: 91.78%
# Epoch 22/100 completed. Training Accuracy: 96.92%, Validation Accuracy: 91.50%
# Epoch 23/100 completed. Training Accuracy: 97.03%, Validation Accuracy: 91.77%
# Epoch 24/100 completed. Training Accuracy: 97.23%, Validation Accuracy: 91.03%
# Epoch 25/100 completed. Training Accuracy: 97.37%, Validation Accuracy: 91.73%
# Epoch 26/100 completed. Training Accuracy: 97.49%, Validation Accuracy: 91.68%
# Epoch 27/100 completed. Training Accuracy: 97.56%, Validation Accuracy: 91.74%
# Epoch 28/100 completed. Training Accuracy: 97.71%, Validation Accuracy: 91.09%
# Epoch 29/100 completed. Training Accuracy: 97.81%, Validation Accuracy: 91.24%
# Epoch 30/100 completed. Training Accuracy: 97.81%, Validation Accuracy: 90.90%
# Epoch 31/100 completed. Training Accuracy: 97.90%, Validation Accuracy: 91.92%
# Epoch 32/100 completed. Training Accuracy: 98.15%, Validation Accuracy: 92.01%
# Epoch 33/100 completed. Training Accuracy: 98.17%, Validation Accuracy: 91.80%
# Epoch 34/100 completed. Training Accuracy: 98.25%, Validation Accuracy: 91.67%
# Epoch 35/100 completed. Training Accuracy: 98.26%, Validation Accuracy: 91.67%
# Epoch 36/100 completed. Training Accuracy: 98.40%, Validation Accuracy: 91.47%
# Epoch 37/100 completed. Training Accuracy: 98.40%, Validation Accuracy: 91.54%
# Epoch 38/100 completed. Training Accuracy: 98.46%, Validation Accuracy: 91.58%
# Epoch 39/100 completed. Training Accuracy: 98.47%, Validation Accuracy: 90.00%
# Epoch 40/100 completed. Training Accuracy: 98.70%, Validation Accuracy: 91.38%
# Epoch 41/100 completed. Training Accuracy: 98.52%, Validation Accuracy: 91.69%
# Epoch 42/100 completed. Training Accuracy: 98.43%, Validation Accuracy: 92.08%
# Epoch 43/100 completed. Training Accuracy: 98.56%, Validation Accuracy: 91.74%
# Epoch 44/100 completed. Training Accuracy: 98.50%, Validation Accuracy: 91.94%
# Epoch 45/100 completed. Training Accuracy: 98.60%, Validation Accuracy: 90.98%
# Epoch 46/100 completed. Training Accuracy: 98.69%, Validation Accuracy: 91.89%
# Epoch 47/100 completed. Training Accuracy: 98.73%, Validation Accuracy: 91.47%
# Epoch 48/100 completed. Training Accuracy: 98.74%, Validation Accuracy: 91.67%
# Epoch 49/100 completed. Training Accuracy: 98.74%, Validation Accuracy: 91.78%
# Epoch 50/100 completed. Training Accuracy: 98.83%, Validation Accuracy: 91.60%
# Epoch 51/100 completed. Training Accuracy: 98.74%, Validation Accuracy: 91.38%
# Epoch 52/100 completed. Training Accuracy: 98.74%, Validation Accuracy: 91.67%
# Epoch 53/100 completed. Training Accuracy: 98.79%, Validation Accuracy: 91.20%
# Epoch 54/100 completed. Training Accuracy: 98.83%, Validation Accuracy: 91.76%
# Epoch 55/100 completed. Training Accuracy: 98.72%, Validation Accuracy: 91.68%
# Epoch 56/100 completed. Training Accuracy: 98.89%, Validation Accuracy: 92.14%
# Epoch 57/100 completed. Training Accuracy: 98.89%, Validation Accuracy: 91.97%
# Epoch 58/100 completed. Training Accuracy: 98.93%, Validation Accuracy: 91.79%
# Epoch 59/100 completed. Training Accuracy: 98.97%, Validation Accuracy: 91.44%
# Epoch 60/100 completed. Training Accuracy: 98.93%, Validation Accuracy: 91.39%
# Epoch 61/100 completed. Training Accuracy: 98.91%, Validation Accuracy: 91.73%
# Epoch 62/100 completed. Training Accuracy: 98.89%, Validation Accuracy: 91.11%
# Epoch 63/100 completed. Training Accuracy: 98.92%, Validation Accuracy: 91.49%
# Epoch 64/100 completed. Training Accuracy: 99.04%, Validation Accuracy: 91.18%
# Epoch 65/100 completed. Training Accuracy: 98.94%, Validation Accuracy: 91.98%
# Epoch 66/100 completed. Training Accuracy: 98.81%, Validation Accuracy: 91.83%
# Epoch 67/100 completed. Training Accuracy: 99.07%, Validation Accuracy: 90.95%
# Epoch 68/100 completed. Training Accuracy: 98.92%, Validation Accuracy: 91.32%
# Epoch 69/100 completed. Training Accuracy: 99.04%, Validation Accuracy: 91.97%
# Epoch 70/100 completed. Training Accuracy: 99.05%, Validation Accuracy: 91.94%
# Epoch 71/100 completed. Training Accuracy: 98.97%, Validation Accuracy: 89.74%
# Epoch 72/100 completed. Training Accuracy: 98.91%, Validation Accuracy: 91.73%
# Epoch 73/100 completed. Training Accuracy: 99.01%, Validation Accuracy: 91.82%
# Epoch 74/100 completed. Training Accuracy: 98.96%, Validation Accuracy: 91.63%
# Epoch 75/100 completed. Training Accuracy: 99.07%, Validation Accuracy: 91.89%
# Epoch 76/100 completed. Training Accuracy: 99.20%, Validation Accuracy: 91.78%
# Epoch 77/100 completed. Training Accuracy: 99.00%, Validation Accuracy: 90.32%
# Epoch 78/100 completed. Training Accuracy: 98.98%, Validation Accuracy: 91.48%
# Epoch 79/100 completed. Training Accuracy: 99.16%, Validation Accuracy: 91.62%
# Epoch 80/100 completed. Training Accuracy: 99.02%, Validation Accuracy: 91.08%
# Epoch 81/100 completed. Training Accuracy: 99.06%, Validation Accuracy: 91.28%
# Epoch 82/100 completed. Training Accuracy: 99.07%, Validation Accuracy: 91.94%
# Epoch 83/100 completed. Training Accuracy: 99.00%, Validation Accuracy: 90.46%
# Epoch 84/100 completed. Training Accuracy: 99.02%, Validation Accuracy: 91.74%
# Epoch 85/100 completed. Training Accuracy: 99.01%, Validation Accuracy: 91.72%
# Epoch 86/100 completed. Training Accuracy: 99.08%, Validation Accuracy: 91.70%
# Epoch 87/100 completed. Training Accuracy: 99.22%, Validation Accuracy: 91.59%
# Epoch 88/100 completed. Training Accuracy: 99.21%, Validation Accuracy: 90.67%
# Epoch 89/100 completed. Training Accuracy: 99.14%, Validation Accuracy: 91.74%
# Epoch 90/100 completed. Training Accuracy: 98.99%, Validation Accuracy: 91.42%
# Epoch 91/100 completed. Training Accuracy: 98.97%, Validation Accuracy: 91.83%
# Epoch 92/100 completed. Training Accuracy: 99.14%, Validation Accuracy: 91.62%
# Epoch 93/100 completed. Training Accuracy: 99.25%, Validation Accuracy: 91.36%
# Epoch 94/100 completed. Training Accuracy: 99.06%, Validation Accuracy: 91.11%
# Epoch 95/100 completed. Training Accuracy: 99.02%, Validation Accuracy: 91.74%
# Epoch 96/100 completed. Training Accuracy: 99.17%, Validation Accuracy: 90.78%
# Epoch 97/100 completed. Training Accuracy: 99.15%, Validation Accuracy: 91.25%
# Epoch 98/100 completed. Training Accuracy: 99.17%, Validation Accuracy: 91.92%
# Epoch 99/100 completed. Training Accuracy: 99.16%, Validation Accuracy: 91.42%
# Epoch 100/100 completed. Training Accuracy: 99.26%, Validation Accuracy: 92.00%
# Hyperparameters: Batch Size=32, Learning Rate=0.01, Rho=0.001, Validation Accuracy=92.0000

# %%
print("Hyperparameter tuning and training with Intel optimization complete.")
print("Best Hyperparameters:")
print("Batch Size:", best_hyperparameters[0])
print("Learning Rate:", best_hyperparameters[1])
print("Rho:", best_hyperparameters[2])


import numpy as np
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import h5py
# Out:
# Hyperparameter tuning and training with Intel optimization complete.
# Best Hyperparameters:
# Batch Size: 32
# Learning Rate: 0.01
# Rho: 0.001
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %% [markdown]
# # Save and load the optimized model

# %%
torch.save(model.state_dict(), "OptimizedModel.pth")


loaded_model = FashionMNISTCNN().to(device)
loaded_model.load_state_dict(torch.load("OptimizedModel.pth"))
loaded_model.eval()
# Out:
# FashionMNISTCNN(
#   (conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=1568, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
#   (relu): ReLU()
#   (nn_layers): ModuleList()
# )

# %% [markdown]
# # Evaluate the model performance with Intel optimization on the test dataset

# %%
test_dataset = FashionMNIST(root="./data", train=False, download=True, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

test_correct_with_opt = 0
test_total_with_opt = 0
all_predicted_probs = []
all_targets = []

with torch.no_grad():
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        output = loaded_model(data)
        _, predicted = torch.max(output.data, 1)
        test_total_with_opt += target.size(0)
        test_correct_with_opt += (predicted == target).sum().item()
        all_predicted_probs.append(output.cpu().numpy())
        all_targets.append(target.cpu().numpy())

test_accuracy_with_opt = 100.0 * test_correct_with_opt / test_total_with_opt
print(f"\nTest Accuracy (With Optimization): {test_accuracy_with_opt:.2f}%")


all_predicted_probs = np.concatenate(all_predicted_probs, axis=0)

if len(all_targets) > 0:
    all_targets = np.concatenate(all_targets, axis=0)
else:
    print("Error: all_targets is empty or contains only one element.")
# Out:
# Test Accuracy (With Optimization): 91.29%

# %%
# Function to plot ROC curve and calculate Intersection over Union (IoU) for multi-class

# %%
def plot_roc_curve(fpr, tpr, class_name):
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve - Class: {class_name}')
    plt.show()

#calculate Intersection over Union (IoU) for multi-class 
def iou(confusion_matrix):
    intersection = np.diag(confusion_matrix)
    union = confusion_matrix.sum(axis=0) + confusion_matrix.sum(axis=1) - intersection
    iou = intersection / union
    return iou

# %% [markdown]
# # One-vs-All and One-vs-One ROC curve

# %%
fpr_ovr = dict()
tpr_ovr = dict()
roc_auc_ovr = dict()

fpr_ovo = dict()
tpr_ovo = dict()
roc_auc_ovo = dict()

# One-vs-All ROC curve
for i in range(10):
    true_labels = (all_targets == i).astype(int)

    fpr_ovr[i], tpr_ovr[i], _ = roc_curve(true_labels, all_predicted_probs[:, i])
    roc_auc_ovr[i] = auc(fpr_ovr[i], tpr_ovr[i])


# Plot One-vs-All ROC curves
for i in range(10):
    class_name = str(i)
    plot_roc_curve(fpr_ovr[i], tpr_ovr[i], class_name)

# %% [markdown]
# # Calculate Intersection over Union (IoU) for multi-class and # Average ROC AUC for One-vs-All and One-vs-One

# %%
conf_matrix = confusion_matrix(all_targets, np.argmax(all_predicted_probs, axis=1))
ious = iou(conf_matrix)
print("Intersection over Union (IoU) per class:")
print(ious)


print("Average One-vs-All ROC AUC:", np.mean(list(roc_auc_ovr.values())))
print("Average One-vs-One ROC AUC:", np.mean(list(roc_auc_ovo.values())))
# Out:
# Intersection over Union (IoU) per class:
# [0.75250836 0.97517378 0.75650714 0.84473198 0.75527039 0.9635468
#  0.59600998 0.92447419 0.96837945 0.93968872]
# Average One-vs-All ROC AUC: 0.9887294944444445
# Average One-vs-One ROC AUC: nan
# /home/u195671/.local/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/u195671/.local/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Output prediction accuracy score report to a file

# %%
predictions = []
targets = []

with torch.no_grad():
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        output = loaded_model(data)
        _, predicted = torch.max(output.data, 1)
        predictions.extend(predicted.cpu().numpy())
        targets.extend(target.cpu().numpy())

report = classification_report(targets, predictions)

with open("PredictionAccuracyScoreReport.txt", "w") as file:
    file.write(report)

print("Prediction accuracy score report saved to 'PredictionAccuracyScoreReport.txt' file.")


with h5py.File("OptimizedModel.h5", "w") as h5_file:
    for name, param in model.named_parameters():
        h5_file.create_dataset(name, data=param.data.cpu().numpy())

print("Optimized model weights saved to 'OptimizedModel.h5'.")


loaded_model = FashionMNISTCNN().to(device)
with h5py.File("OptimizedModel.h5", "r") as h5_file:
    for name, param in loaded_model.named_parameters():
        param.data[:] = torch.tensor(h5_file[name][:]).to(param.data.device)

loaded_model.eval()
# Out:
# Prediction accuracy score report saved to 'PredictionAccuracyScoreReport.txt' file.
# Optimized model weights saved to 'OptimizedModel.h5'.
# FashionMNISTCNN(
#   (conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=1568, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
#   (relu): ReLU()
#   (nn_layers): ModuleList()
# )

# %% [markdown]
# # Get the model summary

# %%
# !pip install torchsummary

from torchsummary import summary
# Specify the input size (e.g., (channels, height, width))
input_size = (1, 28, 28)



summary_str = str(summary(model, input_size=input_size, device=device.type))

# Print the model summary
print(summary_str)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torchsummary in /home/u195671/.local/lib/python3.9/site-packages (1.5.1)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 28, 28]             160
#               ReLU-2           [-1, 16, 28, 28]               0
#          MaxPool2d-3           [-1, 16, 14, 14]               0
#             Conv2d-4           [-1, 32, 14, 14]           4,640
#               ReLU-5           [-1, 32, 14, 14]               0
#          MaxPool2d-6             [-1, 32, 7, 7]               0
#            Flatten-7                 [-1, 1568]               0
#             Linear-8                  [-1, 128]         200,832
#               ReLU-9                  [-1, 128]               0
#            Linear-10                   [-1, 10]           1,290
# ================================================================
# Total params: 206,922
# Trainable params: 206,922
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.34
# Params size (MB): 0.79
# Estimated Total Size (MB): 1.13
# ----------------------------------------------------------------
# None
